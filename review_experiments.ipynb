# %%
from utils.review_experiments import load_display_data, display_details

# %%
df = load_display_data()

# %%
id = int(input('Enter ID for experiment: '))
display_details(df, id)
# Out:
#                       Value
# id                        6
# batch_size               32
# num_epochs              100
# dropout                 0.4
# learning_rate         0.002
# optimizer               sgd
# weight_decay         0.0001
# scheduler              None
# Accuracy               0.46
# model_file        model1.py
# scheduler_params       None
# comment                None
# timestamp              None
