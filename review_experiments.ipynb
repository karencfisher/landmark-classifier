# %%
from utils.review_experiments import load_display_data, display_details

# %%
df = load_display_data()

# %%
id = int(input('Enter ID for experiment: '))
display_details(df, id)
# Out:
#                                                               value
# id                                                               10
# batch_size                                                       32
# num_epochs                                                      120
# dropout                                                        0.15
# learning_rate                                                 0.007
# optimizer                                                       sgd
# weight_decay                                                    0.0
# scheduler         <torch.optim.lr_scheduler.CosineAnnealingLR ob...
# Accuracy                                                     0.5432
# model_file                                                model4.py
# scheduler_params  {"T_max": 200, "eta_min": 0.0, "base_lrs": [0....
# comment                        Over 50%! Not overfit. Noisy though.
# timestamp                                2025-12-28 17:04:23.167916
